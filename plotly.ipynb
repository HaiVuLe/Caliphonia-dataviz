# %%
# plotly standard imports
import plotly.graph_objs as go
import plotly.plotly as py

# Cufflinks wrapper on plotly
import cufflinks

# Data science imports
import pandas as pd
import numpy as np

# Options for pandas
pd.options.display.max_columns = 30

# Display all cell outputs
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = 'all'

from plotly.offline import iplot, plot

cufflinks.go_offline()

# Set global theme
cufflinks.set_config_file(world_readable=True, theme='pearl')
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
df = pd.read_csv('data/vietnamese_restaurant_CA_clean.csv')
df.head()
# Out:
#                                     alias   categories_alias  \
# 0                        pho-vu-la-quinta         vietnamese
# 1                 pho-of-the-desert-indio         vietnamese
# 2    kettles-vietnamese-bistro-santa-rosa         vietnamese
# 3  pho-sonoma-vietnamese-cuisine-petaluma         vietnamese
# 4                         bui-bistro-napa  vietnamese,french
#
#     categories_title  coordinates_latitude  coordinates_longitude  \
# 0         Vietnamese             33.707539            -116.272491
# 1         Vietnamese             33.716305            -116.232306
# 2         Vietnamese             38.459496            -122.732201
# 3         Vietnamese             38.233230            -122.637370
# 4  Vietnamese,French             38.300850            -122.286410
#
#     display_phone                      id  \
# 0  (760) 775-2417  FWhjge1DykCtlVjBU5KhmA
# 1  (760) 775-1500  86ljJKAJv5bLzEVveCrf9g
# 2  (707) 528-3747  wxPfjrSBQWcSRCPy56jA1w
# ...

# %% [markdown]
# # bar plot

# %%
df['location_city'].value_counts()[:10].iplot(
    kind='bar',
    bins=30, 
    xTitle= 'City',
    yTitle= "Number of restaurants",
    title='Top ten California cities with the most Vietnamese restaurants')
# Out:
# <div>
#
#
#             <div id="ee41ad8e-ceed-4200-a357-ec8c4203734e" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("ee41ad8e-ceed-4200-a357-ec8c4203734e")) {
#                     Plotly.newPlot(
#                         'ee41ad8e-ceed-4200-a357-ec8c4203734e',
# ...

# %% [markdown]
# # histogram plot

# %%
df['review_count'].iplot(
    kind='histogram',
    xTitle= 'Number of reviews',
    yTitle= "Number of restaurants",
    title='How much care restaurants receive from their Yelp customers')
# Out:
# <div>
#
#
#             <div id="f3e47579-0d71-4429-ac05-2b4e57f4d600" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("f3e47579-0d71-4429-ac05-2b4e57f4d600")) {
#                     Plotly.newPlot(
#                         'f3e47579-0d71-4429-ac05-2b4e57f4d600',
# ...

# %%
df['review_count'].iplot(
    kind='histogram',
    bins=30, 
    xTitle= 'Number of reviews',
    yTitle= "Number of restaurants")
# Out:
# <div>
#
#
#             <div id="ea5b778a-af5c-49af-aa45-71a308b6f061" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("ea5b778a-af5c-49af-aa45-71a308b6f061")) {
#                     Plotly.newPlot(
#                         'ea5b778a-af5c-49af-aa45-71a308b6f061',
# ...
